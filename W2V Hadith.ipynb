# %%
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
import xlrd
import csv
import os

# %%
def load_data_excel():
    workbook = xlrd.open_workbook(os.getcwd() + '/Dataset/Data Hadis.xlsx')
    worksheet1 = workbook.sheet_by_index(0)
    x = []
    for i in range(2, worksheet1.nrows):
        x.append(worksheet1.cell(i, 2).value)
    return x


def load_data_csv(loc):
    x = []
    with open(loc) as f:
        reader = csv.reader(f)
        for row in reader:
            x.append(row[2])
    return x

# %%
sizes = [100, 200, 300, 400, 500, 600]
windows = [1, 2, 3, 5, 10]

for ii in range(len(sizes)):
    for jj in range(len(windows)):
        
        w = ['nabi', 'tuhan', 'hewan', 'ibadah', 'shalat']
        model1 = Word2Vec.load('Model/sg_hadith_size={}_window={}.model'.format(sizes[ii], windows[jj]))
        model2 = Word2Vec.load('Model/cbow_hadith_size={}_window={}.model'.format(sizes[ii], windows[jj]))
        
        print('Sizes={}, Window={}'.format(sizes[ii], windows[jj]))
        for kk in range(len(w)):
            print('Kata=\t\t\t{}'.format(w[kk]))
            print('Skip-gram model=\t{}'.format(model1.wv.most_similar(positive=w[kk])[:5]))
            print('CBoW model=\t\t{}'.format(model2.wv.most_similar(positive=w[kk])[:5]))
            print()
# Out:
# Sizes=100, Window=1
# Kata=			nabi
# Skip-gram model=	[('rasulullah', 0.8629227876663208), ('rasululullah', 0.7391692399978638), ('rasululllah', 0.731264054775238), ('nabiyullah', 0.720552921295166), ('rasulullahi', 0.7197680473327637)]
# CBoW model=		[('rasulullah', 0.8524163961410522), ('rasulullahi', 0.7446187138557434), ('rasululah', 0.726270318031311), ('rasululllah', 0.7097194194793701), ('nabiyullah', 0.6934483647346497)]
#
# Kata=			tuhan
# Skip-gram model=	[('ilah', 0.7313615083694458), ('rabb', 0.6930239796638489), ('sesembahan', 0.675790548324585), ('rabku', 0.6415878534317017), ('dzat', 0.6279126405715942)]
# CBoW model=		[('rabb', 0.6987307071685791), ('ilah', 0.6746711730957031), ('sesembahan', 0.6564701199531555), ('menungguku', 0.6026139855384827), ('dzat', 0.5956406593322754)]
#
# Kata=			hewan
# ...

# %%
sizes = [100]
windows = [6, 7, 8, 9]

for ii in range(len(sizes)):
    for jj in range(len(windows)):
        
        w = 'nabi'
        model2 = Word2Vec.load('Model/cbow_hadith_size={}_window={}.model'.format(sizes[ii], windows[jj]))
        
        print('Sizes={}, Window={}'.format(sizes[ii], windows[jj]))
        print('CBoW model=\t\t{}'.format(model2.wv.most_similar(positive=w)[0]))
        print()
# Out:
# Sizes=100, Window=6
# CBow model=		('rasulullah', 0.9329395890235901)
#
# Sizes=100, Window=7
# CBow model=		('rasulullah', 0.9274498820304871)
#
# Sizes=100, Window=8
# CBow model=		('rasulullah', 0.9239194393157959)
#
# Sizes=100, Window=9
# CBow model=		('rasulullah', 0.927128791809082)

# %%
model1['nabi']
# Out:
# /Users/fahmisalman/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-4.87955799e-03,  2.85325572e-02, -1.02991961e-01, -5.68826385e-02,
#        -1.63298503e-01,  1.16918869e-02, -4.71011177e-02, -5.09493537e-02,
#         1.42772496e-01, -1.65097535e-01,  3.82437147e-02, -2.99992040e-02,
#        -1.30256146e-01, -1.13761246e-01, -9.78871435e-02, -1.35312349e-01,
#        -1.70676131e-02, -1.10110730e-01, -1.49627045e-01,  8.33424479e-02,
#        -7.30827004e-02, -6.41737208e-02, -3.05252778e-03,  3.16931456e-02,
#         1.14116110e-02,  8.47291276e-02, -1.19955152e-01, -3.41096185e-02,
#         1.87105499e-03, -2.43817985e-01,  1.78836450e-01, -4.57916670e-02,
#        -1.39171422e-01,  2.38580182e-02, -2.06380203e-01,  2.36722842e-01,
# ...

# %%
sum(model1['nabi'])
# Out:
# /Users/fahmisalman/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# -2.9208043375329
